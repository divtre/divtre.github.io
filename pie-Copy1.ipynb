# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF

import numpy as np
import pandas as pd
##import cufflinks as cf
import cufflinks as cf
from matplotlib.pyplot import pie, axis, show
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('age_groupwise.csv')
df
# Out:
#     Year\tAge_Groups\tDeaths
# 0      1999\t5-14 years\t244
# 1    1999\t15-24 years\t3901
# 2    1999\t25-34 years\t5106
# 3    1999\t35-44 years\t6466
# 4    1999\t45-54 years\t5081
# 5    1999\t55-64 years\t2896
# 6    1999\t65-74 years\t2471
# 7    1999\t75-84 years\t2217
# 8       1999\t85+ years\t801
# 9      2000\t5-14 years\t307
# 10   2000\t15-24 years\t3994
# 11   2000\t25-34 years\t4792
# 12   2000\t35-44 years\t6562
# 13   2000\t45-54 years\t5437
# 14   2000\t55-64 years\t2945
# 15   2000\t65-74 years\t2292
# 16   2000\t75-84 years\t2181
# 17      2000\t85+ years\t833
# 18     2001\t5-14 years\t279
# 19   2001\t15-24 years\t3971
# 20   2001\t25-34 years\t5070
# 21   2001\t35-44 years\t6635
# 22   2001\t45-54 years\t5942
# 23   2001\t55-64 years\t3317
# 24   2001\t65-74 years\t2432
# 25   2001\t75-84 years\t2192
# 26      2001\t85+ years\t769
# 27     2002\t5-14 years\t264
# 28   2002\t15-24 years\t4010
# 29   2002\t25-34 years\t5046
# ..                       ...
# ...

# %%
#df=df.set_index('Method')
df.columns
# Out:
# Index(['Year\tAge_Groups\tDeaths'], dtype='object')

# %%
##df_filtered = df.query('Year>1999')
df_1 = df[(df.Year >= 2011)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-d975a7a96929> in <module>()
#       1 ##df_filtered = df.query('Year>1999')
# ----> 2 df_1 = df[(df.Year >= 2011)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Year'

# %%
df_1
# Out:
#      Year   Age_Groups  Deaths
# 120  2011   5-14 years     287
# 121  2011  15-24 years    4822
# 122  2011  25-34 years    6100
# 123  2011  35-44 years    6599
# 124  2011  45-54 years    8858
# 125  2011  55-64 years    6521
# 126  2011  65-74 years    3179
# 127  2011  75-84 years    2174
# 128  2011    85+ years     968
# 129  2011   Not Stated      10
# 130  2012   5-14 years     311
# 131  2012  15-24 years    4872
# 132  2012  25-34 years    6216
# 133  2012  35-44 years    6758
# 134  2012  45-54 years    8862
# 135  2012  55-64 years    6929
# 136  2012  65-74 years    3367
# 137  2012  75-84 years    2232
# 138  2012    85+ years    1049
# 139  2012   Not Stated       4
# 140  2013   5-14 years     395
# 141  2013  15-24 years    4878
# 142  2013  25-34 years    6348
# 143  2013  35-44 years    6551
# 144  2013  45-54 years    8621
# 145  2013  55-64 years    7135
# 146  2013  65-74 years    3794
# 147  2013  75-84 years    2300
# 148  2013    85+ years    1121
# ...

# %%
#ax = sns.barplot(x="Year", y="Deaths", hue="Age_Groups", data=df)

# %%
ay = sns.factorplot(x="Year", y="Deaths",
                    hue="Age_Groups", col="Year",
                   data=df, kind="bar",
                    size=4, aspect=.7);

plt.show()

# %%
ax = sns.barplot(x="Year", y="Deaths", hue="Age_Groups", data=df_1)
plt.show()

# %%
#sns.tsplot(df, time='Year', unit='Deaths',value='Age_Groups')
##sns.tsplot(df_open, time='Date', unit='Dummy', condition='Company', value='Price')
sns.tsplot(df_1, time='Year', unit = 'Deaths', 
               condition='Deaths', value='Age_Groups')
# Out:
# C:\Users\Divya .DESKTOP-O6J5TN1\Anaconda3\lib\site-packages\seaborn\timeseries.py:183: UserWarning:
#
# The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-7f4e690ca611> in <module>()
#       2 ##sns.tsplot(df_open, time='Date', unit='Dummy', condition='Company', value='Price')
#       3 sns.tsplot(df_1, time='Year', unit = 'Deaths',
# ----> 4                condition='Deaths', value='Age_Groups')
#
# ~\Anaconda3\lib\site-packages\seaborn\timeseries.py in tsplot(data, time, unit, condition, value, err_style, ci, interpolate, color, estimator, n_boot, err_palette, err_kws, legend, ax, **kwargs)
#     305         else:
#     306             boot_data = algo.bootstrap(df_c.values, n_boot=n_boot,
# ...

# %%
labels=df.Method
labels
# Out:
# 0     Cut/Pierce
# 1       Drowning
# 2           Fall
# 3        Firearm
# 4      Poisoning
# 5    Suffocation
# Name: Method, dtype: object

# %%
sizes=df.Deaths

# %%
#ax=sns.barplot(x="Method", y="Deaths", data=df)
explode = (0, 0, 0, 0.1,0,0)
colors = ["yellow","green","lightblue","orange","red","purple"]

# %% [markdown]
# ## plt.pie(sizes, explode=explode, labels=labels, colors=colors,
#         autopct="%1.1f%%", shadow=True, startangle=140)

# %%
plt.axis("equal")
# Out:
# (-1.1343579850642533,
#  1.1189041786338532,
#  -1.2125131485292506,
#  1.1289374200921063)

# %%
plt.show()

# %%
df[1].values.tolist()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-23093cb6b78a> in <module>()
# ----> 1 df[1].values.tolist()
#
# ...
